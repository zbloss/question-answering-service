# %%
import os
import random
import time

import nltk
import torch
import weaviate
from nltk.tokenize import sent_tokenize
from transformers import AutoModel, AutoTokenizer

import json
from pydantic import BaseModel

from typing import Optional

# %%
torch.set_grad_enabled(False)

WEAVIATE_URL = 'http://localhost'
WEAVIATE_PORT = '8123'
MODEL_NAME = "distilbert-base-uncased"

wine_filename = '../../data/winemag-data-130k-v2.json'

# %%
with open(wine_filename, 'r') as f:
    data = json.loads(f.read())

# %%
data[0]
# Out:
# {'points': '87',
#  'title': 'Nicosia 2013 Vulkà Bianco  (Etna)',
#  'description': "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.",
#  'taster_name': 'Kerin O’Keefe',
#  'taster_twitter_handle': '@kerinokeefe',
#  'price': None,
#  'designation': 'Vulkà Bianco',
#  'variety': 'White Blend',
#  'region_1': 'Etna',
#  'region_2': None,
#  'province': 'Sicily & Sardinia',
#  'country': 'Italy',
#  'winery': 'Nicosia'}

# %%
class WineItem(BaseModel):
    """
    A WineItem object contains only the relevant 
    fields for our project from the wine dataset.

    It inherits from the Pydantic BaseModel to 
    allow for schema validation.
    """

    title: str
    description: str
    variety: str
    region_1: str
    region_2: Optional[str] = None
    country: str

    @property
    def region(self):
        region = f'{self.region_1} {self.region_2}' if self.region_2 is not None else self.region_1
        return region

# %%
wine_item = WineItem(**data[0])
wine_item.region
# Out:
# 'Etna'

# %%
data[0]
# Out:
# {'points': '87',
#  'title': 'Nicosia 2013 Vulkà Bianco  (Etna)',
#  'description': "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.",
#  'taster_name': 'Kerin O’Keefe',
#  'taster_twitter_handle': '@kerinokeefe',
#  'price': None,
#  'designation': 'Vulkà Bianco',
#  'variety': 'White Blend',
#  'region_1': 'Etna',
#  'region_2': None,
#  'province': 'Sicily & Sardinia',
#  'country': 'Italy',
#  'winery': 'Nicosia'}

# %%
model = AutoModel.from_pretrained(MODEL_NAME)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# initialize nltk (for tokenizing sentences)
nltk.download("punkt")

# initialize weaviate clien{t for importing and searching
client = weaviate.Client(f'{WEAVIATE_URL}:{WEAVIATE_PORT}')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# C:\Users\altoz\AppData\Local\pypoetry\Cache\virtualenvs\qa-service-5CsYAivt-py3.9\lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\altoz\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\altoz\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# C:\Users\altoz\AppData\Local\pypoetry\Cache\virtualenvs\qa-service-5CsYAivt-py3.9\lib\site-packages\weaviate\warnings.py:69: DeprecationWarning: Dep001: You are using the Weaviate Python Client version 3.24.2 which supports
#             changes and features of Weaviate >=1.14.x, but you are connected to Weaviate 1.1.0.
#             If you want to make use of these new changes/features using this Python Client version, upgrade your
#             Weaviate instance.
#   warnings.warn(
# C:\Users\altoz\AppData\Local\pypoetry\Cache\virtualenvs\qa-service-5CsYAivt-py3.9\lib\site-packages\weaviate\warnings.py:112: DeprecationWarning: Dep004: You are connected to Weaviate 1.1.0.
#             Please consider upgrading to the latest version. See https://www.weaviate.io/developers/weaviate for details.
#   warnings.warn(

# %%
def get_post_filenames(limit_objects=100, posts_directory: str = POSTS_DIRECTORY):
    file_names = []
    i = 0
    for root, dirs, files in os.walk(posts_directory):
        for filename in files:
            path = os.path.join(root, filename)
            file_names += [path]

    random.shuffle(file_names)
    limit_objects = min(len(file_names), limit_objects)

    file_names = file_names[:limit_objects]

    return file_names


def read_posts(filenames=[]):
    posts = []
    for filename in filenames:
        f = open(filename, encoding="utf-8", errors="ignore")
        post = f.read()

        # strip the headers (the first occurrence of two newlines)
        post = post[post.find("\n\n") :]

        # remove posts with less than 10 words to remove some of the noise
        if len(post.split(" ")) < 10:
            continue

        post = post.replace("\n", " ").replace("\t", " ").strip()
        if len(post) > 1000:
            post = post[:1000]
        posts += [post]

    return posts


def text2vec(text):
    tokens_pt = tokenizer(
        text,
        padding=True,
        truncation=True,
        max_length=500,
        add_special_tokens=True,
        return_tensors="pt",
    )
    outputs = model(**tokens_pt)
    return outputs[0].mean(0).mean(0).detach()


def vectorize_posts(posts=[]):
    post_vectors = []
    before = time.time()
    for i, post in enumerate(posts):
        vec = text2vec(sent_tokenize(post))
        post_vectors += [vec]
        if i % 100 == 0 and i != 0:
            print("So far {} objects vectorized in {}s".format(i, time.time() - before))
    after = time.time()

    print("Vectorized {} items in {}s".format(len(posts), after - before))

    return post_vectors


def init_weaviate_schema():
    # a simple schema containing just a single class for our posts
    schema = {
        "classes": [
            {
                "class": "Post",
                "vectorizer": "none",  # explicitly tell Weaviate not to vectorize anything, we are providing the vectors ourselves through our BERT model
                "properties": [
                    {
                        "name": "content",
                        "dataType": ["text"],
                    }
                ],
            }
        ]
    }

    # cleanup from previous runs
    client.schema.delete_all()

    client.schema.create(schema)


def import_posts_with_vectors(posts, vectors, batchsize=256):
    batch = weaviate.ObjectsBatchRequest()

    for i, post in enumerate(posts):
        props = {
            "content": post,
        }
        batch.add(props, "Post", vector=vectors[i])

        # when either batch size is reached or we are at the last object
        if (i != 0 and i % batchsize == 0) or i == len(posts) - 1:
            # send off the batch
            client.batch.create(batch)

            # and reset for the next batch
            batch = weaviate.ObjectsBatchRequest()


def search(query="", limit=3):
    before = time.time()
    vec = text2vec(query)
    vec_took = time.time() - before

    before = time.time()
    near_vec = {"vector": vec.tolist()}
    res = (
        client.query.get("Post", ["content", "_additional {certainty}"])
        .with_near_vector(near_vec)
        .with_limit(limit)
        .do()
    )
    search_took = time.time() - before

    print(
        '\nQuery "{}" with {} results took {:.3f}s ({:.3f}s to vectorize and {:.3f}s to search)'.format(
            query, limit, vec_took + search_took, vec_took, search_took
        )
    )
    for post in res["data"]["Get"]["Post"]:
        print("{:.4f}: {}".format(post["_additional"]["certainty"], post["content"]))
        print("---")

# %%
init_weaviate_schema()

# %%
posts = read_posts(get_post_filenames(4000))
# Out:
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104955' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54589' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\77815' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\61044' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67414' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84435' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\61281' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54110' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104816' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59543' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16079' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84135' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\15959' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54512' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10780' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54032' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104869' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16145' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54325' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76845' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67500' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76203' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103134' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52048' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\55488' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103037' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38794' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39031' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16078' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76686' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/soc.religion.christian\\21526' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54711' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\76442' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38933' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54079' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\83944' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84007' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105000' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\105125' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\104807' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67552' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/alt.atheism\\53335' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38761' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10185' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67447' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/alt.atheism\\53644' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76648' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54234' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/alt.atheism\\53804' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10170' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/soc.religion.christian\\21677' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67413' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54625' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\15965' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\76474' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103332' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\178781' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16150' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\55106' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54279' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54005' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76442' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\179109' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\60963' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\68087' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\61059' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67983' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\60774' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104938' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105081' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\60801' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67984' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59498' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104860' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59299' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10035' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39662' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\77818' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104997' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\77348' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10048' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54892' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54618' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52440' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16076' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59510' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\179091' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103077' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10191' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\51955' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\178870' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/soc.religion.christian\\21498' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105079' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\76459' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\15810' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38886' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67432' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54855' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39661' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76478' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103811' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84312' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\104738' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54550' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103372' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\77256' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67482' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\61417' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54222' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10155' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103204' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10855' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103665' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16026' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\15870' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54916' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59619' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\178770' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105058' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/alt.atheism\\53806' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\51973' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67572' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.autos\\103160' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\55104' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104656' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\68232' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54183' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52010' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\76480' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\51999' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59617' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\53886' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76853' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104755' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38958' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39022' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10102' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76805' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\61056' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.misc\\179076' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10123' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84298' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ...
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54535' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.med\\59538' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\104973' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/soc.religion.christian\\21516' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\61012' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54086' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67562' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54483' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39637' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54141' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54211' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105158' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10613' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/soc.religion.christian\\21546' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\16105' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\53952' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104977' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54072' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\104876' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104989' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\61280' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52055' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.motorcycles\\105128' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52244' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\62479' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\68225' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\39053' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.crypt\\15794' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.hockey\\54523' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\105145' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\61133' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.religion.misc\\84442' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.mideast\\77183' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.windows.x\\67446' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38771' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10112' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.ibm.pc.hardware\\60883' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\61430' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/talk.politics.guns\\54866' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.graphics\\38861' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/rec.sport.baseball\\104670' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.electronics\\54308' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76780' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/misc.forsale\\76364' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.sys.mac.hardware\\52192' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\3880419246.py:20: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/comp.os.ms-windows.misc\\10133' mode='r' encoding='utf-8'>
#   f = open(filename, encoding="utf-8", errors="ignore")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\altoz\AppData\Local\Temp\ipykernel_23068\398582599.py:1: ResourceWarning: unclosed file <_io.TextIOWrapper name='../../data/20news-bydate-test/sci.space\\61358' mode='r' encoding='utf-8'>
#   posts = read_posts(get_post_filenames(4000))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
vectors = vectorize_posts(posts[:500])
# Out:
# So far 100 objects vectorized in 10.208102226257324s
# So far 200 objects vectorized in 19.52180314064026s
# So far 300 objects vectorized in 29.140095472335815s
# So far 400 objects vectorized in 39.7047061920166s
# Vectorized 500 items in 49.48389959335327s

# %%
import_posts_with_vectors(posts[:500], vectors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import_posts_with_vectors(posts[:500], vectors)
#
# Cell In[21], line 90, in import_posts_with_vectors(posts, vectors, batchsize)
#      89 def import_posts_with_vectors(posts, vectors, batchsize=256):
# ---> 90     batch = weaviate.ObjectsBatchRequest()
#      92     for i, post in enumerate(posts):
#      93         props = {
#      94             "content": post,
#      95         }
#
# AttributeError: module 'weaviate' has no attribute 'ObjectsBatchRequest'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 vectors.shape
#
# NameError: name 'vectors' is not defined

# %%
search("the best camera lens", 1)
search("which software do i need to view jpeg files", 1)
search("windows vs mac", 1)
